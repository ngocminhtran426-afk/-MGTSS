# %% [markdown]
# # 🎬 VideoLingo - Chạy trên Google Colab
# Notebook này giúp bạn thiết lập và chạy tool trên Google Colab.

# %%
# 1. Clone Source Code từ GitHub
# !git clone https://github.com/ngocminhtran426-afk/-MGTSS.git
# %cd -MGTSS

# %%
# 2. Cài đặt các thư viện cần thiết
# !pip install -r requirements.txt
# !pip install streamlit-cropper pyngrok

# %%
# 3. Cài đặt VideoSubFinder cho Linux (Dùng cho OCR)
# !wget https://github.com/eritpchy/videosubfinder-cli/releases/download/v1.0.0/VideoSubFinderCli-Ubuntu-20.04.tar.gz -O vsf.tar.gz
# !tar -xvf vsf.tar.gz -C core/libs/ocr
# !chmod +x core/libs/ocr/VideoSubFinderCli

# %%
# 4. Chạy Streamlit App qua LocalTunnel
# !npm install -g localtunnel
import urllib.request
print('Mật khẩu LocalTunnel của bạn là:', urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip())
# !streamlit run st.py & npx localtunnel --port 8501
